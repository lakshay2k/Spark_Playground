# %% [markdown]
# ### Step 1: import spark context

# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder\
        .master("local")\
        .appName("Experiment 3")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 2: Load the movies.txt

# %%
#movies.txt files uploaded
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 3: Create a RDD form movies.txt file using textFile()

# %%
movies = sc.textFile("dbfs:/FileStore/shared_uploads/500068760@stu.upes.ac.in/movies.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 4: Display records

# %%
movies.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [&#34;1::Toy Story (1995)::Animation|Children&#39;s|Comedy&#34;,
#  &#34;2::Jumanji (1995)::Adventure|Children&#39;s|Fantasy&#34;,
#  &#39;3::Grumpier Old Men (1995)::Comedy|Romance&#39;,
#  &#39;4::Waiting to Exhale (1995)::Comedy|Drama&#39;,
#  &#39;5::Father of the Bride Part II (1995)::Comedy&#39;,
#  &#39;6::Heat (1995)::Action|Crime|Thriller&#39;,
#  &#39;7::Sabrina (1995)::Comedy|Romance&#39;,
#  &#34;8::Tom and Huck (1995)::Adventure|Children&#39;s&#34;,
#  &#39;9::Sudden Death (1995)::Action&#39;,
#  &#39;10::GoldenEye (1995)::Action|Adventure|Thriller&#39;]</div>

# %% [markdown]
# ### Step 5: Split the RDD based on '::' as delimiter

# %%
movies_split = movies.map(lambda line : line.split("::"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_split.take(4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [[&#39;1&#39;, &#39;Toy Story (1995)&#39;, &#34;Animation|Children&#39;s|Comedy&#34;],
#  [&#39;2&#39;, &#39;Jumanji (1995)&#39;, &#34;Adventure|Children&#39;s|Fantasy&#34;],
#  [&#39;3&#39;, &#39;Grumpier Old Men (1995)&#39;, &#39;Comedy|Romance&#39;],
#  [&#39;4&#39;, &#39;Waiting to Exhale (1995)&#39;, &#39;Comedy|Drama&#39;]]</div>

# %% [markdown]
# ### Step 6: Select only movies fields containing movie names - (second index)

# %%
movies_names = movies_split.map(lambda name : name[1])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_names.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [&#39;Toy Story (1995)&#39;,
#  &#39;Jumanji (1995)&#39;,
#  &#39;Grumpier Old Men (1995)&#39;,
#  &#39;Waiting to Exhale (1995)&#39;,
#  &#39;Father of the Bride Part II (1995)&#39;]</div>

# %% [markdown]
# ### Step 7: Find the movies released in 1993 using filter()

# %%
movies_release = movies_names.filter(lambda name : "1993" in name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_release.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: [&#39;Boys of St. Vincent, The (1993)&#39;,
#  &#39;Love &amp; Human Remains (1993)&#39;,
#  &#39;My Crazy Life (Mi vida loca) (1993)&#39;,
#  &#39;Beyond Bedlam (1993)&#39;,
#  &#39;Three Colors: Blue (1993)&#39;,
#  &#39;Suture (1993)&#39;,
#  &#39;Strawberry and Chocolate (Fresa y chocolate) (1993)&#39;,
#  &#34;What&#39;s Eating Gilbert Grape (1993)&#34;,
#  &#39;Backbeat (1993)&#39;,
#  &#39;Wonderful, Horrible Life of Leni Riefenstahl, The (Die Macht der Bilder) (1993)&#39;]</div>

# %% [markdown]
# ### Step 8: Count the number of movies released in 1993

# %%
movies_release.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: 165</div>

# %% [markdown]
# ### Step 9: Test SparkSession variable

# %%
spark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: </div>
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.172.238.123:48695">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Step 10: Demonstrate the lambda function - length

# %%
movies_names_length = movies_names.map(lambda x : len(x))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_names_length.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: [16, 14, 23, 24, 34, 11, 14, 19, 19, 16]</div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
